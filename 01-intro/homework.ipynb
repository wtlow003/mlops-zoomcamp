# %%
# !python -V
# Out:
# Python 3.8.10

# %% [markdown]
# # Load Packages

# %%
import warnings

import pandas as pd
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
warnings.filterwarnings("ignore")

# %% [markdown]
# # Data Ingestion

# %%
df_train = pd.read_parquet("data/yellow_tripdata_2022-01.parquet")
df_val = pd.read_parquet("data/yellow_tripdata_2022-02.parquet")

# %%
df_train
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0               1  2022-01-01 00:35:40   2022-01-01 00:53:29              2.0  \
# 1               1  2022-01-01 00:33:43   2022-01-01 00:42:07              1.0
# 2               2  2022-01-01 00:53:21   2022-01-01 01:02:19              1.0
# 3               2  2022-01-01 00:25:21   2022-01-01 00:35:23              1.0
# 4               2  2022-01-01 00:36:48   2022-01-01 01:14:20              1.0
# ...           ...                  ...                   ...              ...
# 2463926         2  2022-01-31 23:36:53   2022-01-31 23:42:51              NaN
# 2463927         2  2022-01-31 23:44:22   2022-01-31 23:55:01              NaN
# 2463928         2  2022-01-31 23:39:00   2022-01-31 23:50:00              NaN
# 2463929         2  2022-01-31 23:36:42   2022-01-31 23:48:45              NaN
# 2463930         2  2022-01-31 23:46:00   2022-02-01 00:13:00              NaN
#
# ...

# %%
df_val
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0               1  2022-02-01 00:06:58   2022-02-01 00:19:24              1.0  \
# 1               1  2022-02-01 00:38:22   2022-02-01 00:55:55              1.0
# 2               1  2022-02-01 00:03:20   2022-02-01 00:26:59              1.0
# 3               2  2022-02-01 00:08:00   2022-02-01 00:28:05              1.0
# 4               2  2022-02-01 00:06:48   2022-02-01 00:33:07              1.0
# ...           ...                  ...                   ...              ...
# 2979426         2  2022-02-28 23:50:00   2022-03-01 00:06:00              NaN
# 2979427         2  2022-02-28 23:06:57   2022-02-28 23:19:12              NaN
# 2979428         2  2022-02-28 23:48:13   2022-03-01 00:03:33              NaN
# 2979429         2  2022-02-28 23:56:41   2022-03-01 00:04:57              NaN
# 2979430         2  2022-02-28 23:04:00   2022-02-28 23:10:00              NaN
#
# ...

# %%
print(df_train.columns)
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %% [markdown]
# # `Q1.` Read the data for January. How many columns are there?

# %%
print(f"There are {df_train.shape[0]} rows and {df_train.shape[1]} columns.")
# Out:
# There are 2463931 rows and 19 columns.

# %% [markdown]
# # `Q2.` Computing duration

# %%
# generate duration for both train and val
df_train["duration"] = df_train.tpep_dropoff_datetime - df_train.tpep_pickup_datetime
df_train["duration"] = df_train["duration"].apply(lambda td: td.total_seconds() / 60)

# %%
# what is the std for jan trips?
print(f"Standard deviation for Jan's trip: {df_train['duration'].std()}")
# Out:
# Standard deviation for Jan's trip: 46.44530513776802

# %% [markdown]
# # `Q3.` Dropping outliers

# %%
df_train = df_train[(df_train.duration >= 1) & (df_train.duration <= 60)]

# %%
print(f"There are {df_train.shape[0]} rows and {df_train.shape[1]} columns.")
# Out:
# There are 2421440 rows and 20 columns.

# %%
original = 2463931
current = 2421440

print(f"Dropped of records : {((original - current) / original) * 100:.2f}%")
# Out:
# Dropped of records : 1.72%

# %% [markdown]
# # `Q4.` One-hot encoding

# %%
categorical = ["PULocationID", "DOLocationID"]
print(df_train[categorical].dtypes)
# Out:
# PULocationID    int64
# DOLocationID    int64
# dtype: object

# %%
df_train[categorical] = df_train[categorical].astype(str)
print(df_train[categorical].dtypes)
# Out:
# PULocationID    object
# DOLocationID    object
# dtype: object

# %%
train_dicts = df_train[categorical].to_dict(orient="records")

# %%
dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

# %%
X_train
# Out:
# <2421440x515 sparse matrix of type '<class 'numpy.float64'>'
# 	with 4842880 stored elements in Compressed Sparse Row format>

# %%
print(f"Total of {X_train.shape[1]} columns")
# Out:
# Total of 515 columns

# %% [markdown]
# # `Q5.` Training a model

# %%
y_train = df_train["duration"].values
print(y_train)
# Out:
# [17.81666667  8.4         8.96666667 ... 11.         12.05
#  27.        ]

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train)
print(mean_squared_error(y_train, y_pred, squared=False))
# Out:
# 6.986191065500608

# %% [markdown]
# # `Q6.` Evaluating the model

# %%
df_val["duration"] = df_val.tpep_dropoff_datetime - df_val.tpep_pickup_datetime
df_val["duration"] = df_val["duration"].apply(lambda td: td.total_seconds() / 60)

# %%
df_val
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count
# 0               1  2022-02-01 00:06:58   2022-02-01 00:19:24              1.0  \
# 1               1  2022-02-01 00:38:22   2022-02-01 00:55:55              1.0
# 2               1  2022-02-01 00:03:20   2022-02-01 00:26:59              1.0
# 3               2  2022-02-01 00:08:00   2022-02-01 00:28:05              1.0
# 4               2  2022-02-01 00:06:48   2022-02-01 00:33:07              1.0
# ...           ...                  ...                   ...              ...
# 2979426         2  2022-02-28 23:50:00   2022-03-01 00:06:00              NaN
# 2979427         2  2022-02-28 23:06:57   2022-02-28 23:19:12              NaN
# 2979428         2  2022-02-28 23:48:13   2022-03-01 00:03:33              NaN
# 2979429         2  2022-02-28 23:56:41   2022-03-01 00:04:57              NaN
# 2979430         2  2022-02-28 23:04:00   2022-02-28 23:10:00              NaN
#
# ...

# %%
df_val[categorical] = df_val[categorical].astype(str)
print(df_val[categorical].dtypes)
# Out:
# PULocationID    object
# DOLocationID    object
# dtype: object

# %%
val_dicts = df_val[categorical].to_dict(orient="records")

# %%
X_val = dv.transform(val_dicts)

# %%
y_val = df_val["duration"].values

# %%
y_pred = lr.predict(X_val)

print(mean_squared_error(y_val, y_pred, squared=False))
# Out:
# 46.87727583354224
